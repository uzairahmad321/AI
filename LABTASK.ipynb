# %%
# Tree Node Definition
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

# Breadth-First Search (BFS) on a Tree
def tree_bfs(root):
    if not root:
        return

    queue = [root]
    result = []

    while queue:
        current = queue.pop(0)
        result.append(current.val)

        if current.left:
            queue.append(current.left)
        if current.right:
            queue.append(current.right)

    return result

# Depth-First Search (DFS) on a Tree (Preorder)
def tree_dfs_preorder(root):
    if not root:
        return []

    result = []
    stack = [root]

    while stack:
        current = stack.pop()
        result.append(current.val)

        if current.right:
            stack.append(current.right)
        if current.left:
            stack.append(current.left)

    return result

# Depth-First Search (DFS) on a Tree (Inorder)
def tree_dfs_inorder(root):
    if not root:
        return []

    result = []
    stack = []
    current = root

    while current or stack:
        while current:
            stack.append(current)
            current = current.left

        current = stack.pop()
        result.append(current.val)
        current = current.right

    return result

# Depth-First Search (DFS) on a Tree (Postorder)
def tree_dfs_postorder(root):
    if not root:
        return []

    result = []
    stack1 = [root]
    stack2 = []

    while stack1:
        current = stack1.pop()
        stack2.append(current)

        if current.left:
            stack1.append(current.left)
        if current.right:
            stack1.append(current.right)

    while stack2:
        result.append(stack2.pop().val)

    return result

# %%
from collections import deque

# Graph Node Definition
class GraphNode:
    def __init__(self, val):
        self.val = val
        self.neighbors = []

# Breadth-First Search (BFS) on a Graph
def graph_bfs(start):
    if not start:
        return

    queue = deque([start])
    visited = set()
    result = []

    while queue:
        current = queue.popleft()

        if current in visited:
            continue

        result.append(current.val)
        visited.add(current)

        for neighbor in current.neighbors:
            if neighbor not in visited:
                queue.append(neighbor)

    return result

# Depth-First Search (DFS) on a Graph
def graph_dfs(start):
    if not start:
        return []

    visited = set()
    result = []

    def dfs_helper(node):
        if node in visited:
            return

        visited.add(node)
        result.append(node.val)

        for neighbor in node.neighbors:
            dfs_helper(neighbor)

    dfs_helper(start)

    return result

# %% [markdown]
# TASK **2**

# %%
import random

class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def insert_node(root, val):
    if not root:
        return TreeNode(val)

    if val < root.val:
        root.left = insert_node(root.left, val)
    else:
        root.right = insert_node(root.right, val)

    return root

def build_tree(numbers):
    if not numbers:
        return None

    root = None
    for num in numbers:
        root = insert_node(root, num)

    return root

# Example usage
numbers_1000 = [random.randint(1, 1000) for _ in range(1000)]
tree_1000 = build_tree(numbers_1000)

numbers_40000 = [random.randint(1, 40000) for _ in range(40000)]
tree_40000 = build_tree(numbers_40000)

numbers_80000 = [random.randint(1, 80000) for _ in range(80000)]
tree_80000 = build_tree(numbers_80000)

numbers_200000 = [random.randint(1, 200000) for _ in range(200000)]
tree_200000 = build_tree(numbers_200000)

numbers_1000000 = [random.randint(1, 1000000) for _ in range(1000000)]
tree_1000000 = build_tree(numbers_1000000)

# Print the tree structure
def print_tree(root):
    if root:
        print(root.val)
        print_tree(root.left)
        print_tree(root.right)

print("Tree for numbers_1000:")
print_tree(tree_1000)

print("Tree for numbers_40000:")
print_tree(tree_40000)

print("Tree for numbers_80000:")
# 999834
# 999834
# 999849
# 999848
# 999841
# 999838
# 999837
# 999837
# 999839
# 999845
# 999848
# 999849
# 999852
# 999851
# 999851
# 999874
# 999871
# 999859
# 999858
# 999856
# 999855
# 999854
# 999855
# 999857
# 999858
# 999868
# 999867
# 999860
# 999867
# 999868
# 999869
# 999871
# 999873
# 999873
# 999884
# 999882
# 999879
# 999874
# 999877
# 999877
# 999879
# 999883
# 999901
# 999894
# 999890
# 999887
# 999889
# 999888
# 999887
# 999893
# 999891
# 999896
# 999895
# 999895
# 999897
# 999896
# 999896
# 999900
# 999898
# 999899
# 999910
# 999903
# 999906
# 999904
# 999909
# 999907
# 999906
# 999909
# 999915
# 999911
# 999910
# 999911
# 999918
# 999916
# 999918
# 999919
# 999923
# 999955
# 999929
# 999927
# 999928
# 999927
# 999928
# 999931
# 999930
# 999929
# 999938
# 999934
# 999936
# 999936
# 999954
# 999950
# 999947
# 999942
# 999941
# 999940
# 999941
# 999946
# 999949
# 999951
# 999969
# 999964
# 999958
# 999961
# 999960
# 999960
# 999968
# 999966
# 999964
# 999966
# 999977
# 999972
# 999970
# 999969
# 999973
# 999974
# 999976
# 999975
# 999994
# 999977
# 999986
# 999977
# 999979
# 999978
# 999978
# 999981
# 999979
# 999984
# 999982
# 999985
# 999985
# 999986
# 999991
# 999987
# 999990
# 999998
# 999996
# 999995
# 1000000
# 999999

# %% [markdown]
# Part **2**

# %%
import random
import time

class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def insert_node(root, val):
    if not root:
        return TreeNode(val)

    if val < root.val:
        root.left = insert_node(root.left, val)
    else:
        root.right = insert_node(root.right, val)

    return root

def build_tree(numbers):
    if not numbers:
        return None

    root = None
    for num in numbers:
        root = insert_node(root, num)

    return root

def bfs(root):
    if not root:
        return []

    queue = [root]
    result = []

    while queue:
        current = queue.pop(0)
        result.append(current.val)

        if current.left:
            queue.append(current.left)
        if current.right:
            queue.append(current.right)

    return result

def dfs_preorder(root):
    if not root:
        return []

    result = []
    stack = [root]

    while stack:
        current = stack.pop()
        result.append(current.val)

        if current.right:
            stack.append(current.right)
        if current.left:
            stack.append(current.left)

    return result

def dfs_inorder(root):
    if not root:
        return []

    result = []
    stack = []
    current = root

    while current or stack:
        while current:
            stack.append(current)
            current = current.left

        current = stack.pop()
        result.append(current.val)
        current = current.right

    return result

def dfs_postorder(root):
    if not root:
        return []

    result = []
    stack1 = [root]
    stack2 = []

    while stack1:
        current = stack1.pop()
        stack2.append(current)

        if current.left:
            stack1.append(current.left)
        if current.right:
            stack1.append(current.right)

    while stack2:
        result.append(stack2.pop().val)

    return result

# Example usage
numbers_1000 = [random.randint(1, 1000) for _ in range(1000)]
tree_1000 = build_tree(numbers_1000)

numbers_40000 = [random.randint(1, 40000) for _ in range(40000)]
tree_40000 = build_tree(numbers_40000)

numbers_80000 = [random.randint(1, 80000) for _ in range(80000)]
tree_80000 = build_tree(numbers_80000)

numbers_200000 = [random.randint(1, 200000) for _ in range(200000)]
tree_200000 = build_tree(numbers_200000)



# Measure BFS execution time
start_time = time.time()
bfs_result_1000 = bfs(tree_1000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_1000:", execution_time)

start_time = time.time()
bfs_result_40000 = bfs(tree_40000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_40000:", execution_time)

start_time = time.time()
bfs_result_80000 = bfs(tree_80000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_80000:", execution_time)

start_time = time.time()
bfs_result_200000 = bfs(tree_200000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_200000:", execution_time)

start_time = time.time()
bfs_result_1000000 = bfs(tree_1000000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_1000000:", execution_time)

# Measure DFS execution time
start_time = time.time()
dfs_result_1000 = dfs_preorder(tree_1000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_1000:", execution_time)

start_time = time.time()
dfs_result_40000 = dfs_preorder(tree_40000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_40000:", execution_time)

start_time = time.time()
dfs_result_80000 = dfs_preorder(tree_80000)
import random
import time

class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def insert_node(root, val):
    if not root:
        return TreeNode(val)

    if val < root.val:
        root.left = insert_node(root.left, val)
    else:
        root.right = insert_node(root.right, val)

    return root

def build_tree(numbers):
    if not numbers:
        return None

    root = None
    for num in numbers:
        root = insert_node(root, num)

    return root

def bfs(root):
    if not root:
        return []

    queue = [root]
    result = []

    while queue:
        current = queue.pop(0)
        result.append(current.val)

        if current.left:
            queue.append(current.left)
        if current.right:
            queue.append(current.right)

    return result

def dfs_preorder(root):
    if not root:
        return []

    result = []
    stack = [root]

    while stack:
        current = stack.pop()
        result.append(current.val)

        if current.right:
            stack.append(current.right)
        if current.left:
            stack.append(current.left)

    return result

def dfs_inorder(root):
    if not root:
        return []

    result = []
    stack = []
    current = root

    while current or stack:
        while current:
            stack.append(current)
            current = current.left

        current = stack.pop()
        result.append(current.val)
        current = current.right

    return result

def dfs_postorder(root):
    if not root:
        return []

    result = []
    stack1 = [root]
    stack2 = []

    while stack1:
        current = stack1.pop()
        stack2.append(current)

        if current.left:
            stack1.append(current.left)
        if current.right:
            stack1.append(current.right)

    while stack2:
        result.append(stack2.pop().val)

    return result

# Example usage
numbers_1000 = [random.randint(1, 1000) for _ in range(1000)]
tree_1000 = build_tree(numbers_1000)

numbers_40000 = [random.randint(1, 40000) for _ in range(40000)]
tree_40000 = build_tree(numbers_40000)

numbers_80000 = [random.randint(1, 80000) for _ in range(80000)]
tree_80000 = build_tree(numbers_80000)

numbers_200000 = [random.randint(1, 200000) for _ in range(200000)]
tree_200000 = build_tree(numbers_200000)

numbers_1000000 = [random.randint(1, 1000000) for _ in range(1000000)]
tree_1000000 = build_tree(numbers_1000000)

# Measure BFS execution time
start_time = time.time()
bfs_result_1000 = bfs(tree_1000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_1000:", execution_time)

start_time = time.time()
bfs_result_40000 = bfs(tree_40000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_40000:", execution_time)

start_time = time.time()
bfs_result_80000 = bfs(tree_80000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_80000:", execution_time)

start_time = time.time()
bfs_result_200000 = bfs(tree_200000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_200000:", execution_time)

start_time = time.time()
bfs_result_1000000 = bfs(tree_1000000)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time for numbers_1000000:", execution_time)

# Measure DFS execution time
start_time = time.time()
dfs_result_1000 = dfs_preorder(tree_1000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_1000:", execution_time)

start_time = time.time()
dfs_result_40000 = dfs_preorder(tree_40000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_40000:", execution_time)

start_time = time.time()
dfs_result_80000 = dfs_preorder(tree_80000)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time for numbers_80000:", execution_time)
# Out:
# BFS Execution Time for numbers_1000: 0.0009641647338867188
# BFS Execution Time for numbers_40000: 0.2274477481842041
# BFS Execution Time for numbers_80000: 0.38900017738342285
# BFS Execution Time for numbers_200000: 7.109493255615234
# BFS Execution Time for numbers_1000000: 79.33827877044678
# DFS Execution Time for numbers_1000: 0.0009734630584716797
# DFS Execution Time for numbers_40000: 0.07246279716491699
# BFS Execution Time for numbers_1000: 0.0006825923919677734
# BFS Execution Time for numbers_40000: 0.04292941093444824
# BFS Execution Time for numbers_80000: 0.13552474975585938
# BFS Execution Time for numbers_200000: 1.2688632011413574
# BFS Execution Time for numbers_1000000: 11.77934718132019
# DFS Execution Time for numbers_1000: 0.0009684562683105469
# DFS Execution Time for numbers_40000: 0.12922978401184082
# DFS Execution Time for numbers_80000: 0.07224631309509277

# %% [markdown]
# PART **3**

# %%
import random
import time

def bfs(lis, goal):
    if not lis:
        return None

    queue = [(lis, 0)]
    visited = set()

    while queue:
        current, depth = queue.pop(0)
        visited.add(tuple(current))

        if current[-220:] == goal:
            return depth

        for i in range(len(current)):
            new_list = current[:i] + current[i+1:]
            if tuple(new_list) not in visited:
                queue.append((new_list, depth + 1))

    return -1

def dfs(lis, goal):
    if not lis:
        return None

    stack = [(lis, 0)]
    visited = set()

    while stack:
        current, depth = stack.pop()
        visited.add(tuple(current))

        if current[-220:] == goal:
            return depth

        for i in range(len(current)):
            new_list = current[:i] + current[i+1:]
            if tuple(new_list) not in visited:
                stack.append((new_list, depth + 1))

    return -1

# Example usage
random.seed(42)  # Set random seed for reproducibility

# Generate a random set of numbers
total_len = 1000
lis = [random.randint(1, 1000) for _ in range(total_len)]

goal = lis[total_len - 220:]

# Measure BFS execution time
start_time = time.time()
bfs_depth = bfs(lis, goal)
end_time = time.time()
execution_time = end_time - start_time
print("BFS Execution Time:", execution_time)
print("BFS Depth:", bfs_depth)

# Measure DFS execution time
start_time = time.time()
dfs_depth = dfs(lis, goal)
end_time = time.time()
execution_time = end_time - start_time
print("DFS Execution Time:", execution_time)
print("DFS Depth:", dfs_depth)
# Out:
# BFS Execution Time: 6.961822509765625e-05
# BFS Depth: 0
# DFS Execution Time: 8.416175842285156e-05
# DFS Depth: 0

# %% [markdown]
# PART5

# %%
import random
import time
import matplotlib.pyplot as plt

def bfs(lis, goal):
    if not lis:
        return None

    queue = [(lis, 0)]
    visited = set()

    while queue:
        current, depth = queue.pop(0)
        visited.add(tuple(current))

        if current[-220:] == goal:
            return depth

        for i in range(len(current)):
            new_list = current[:i] + current[i+1:]
            if tuple(new_list) not in visited:
                queue.append((new_list, depth + 1))

    return -1

def dfs(lis, goal):
    if not lis:
        return None

    stack = [(lis, 0)]
    visited = set()

    while stack:
        current, depth = stack.pop()
        visited.add(tuple(current))

        if current[-220:] == goal:
            return depth

        for i in range(len(current)):
            new_list = current[:i] + current[i+1:]
            if tuple(new_list) not in visited:
                stack.append((new_list, depth + 1))

    return -1

# Example usage
random.seed(42)  # Set random seed for reproducibility

# Input sizes
input_sizes = [1000, 40000, 80000, 200000, 1000000]

# Execution times
bfs_execution_times = []
dfs_execution_times = []

for total_len in input_sizes:
    lis = [random.randint(1, 1000) for _ in range(total_len)]
    goal = lis[total_len - 220:]

    # Measure BFS execution time
    start_time = time.time()
    bfs_depth = bfs(lis, goal)
    end_time = time.time()
    bfs_execution_time = end_time - start_time
    bfs_execution_times.append(bfs_execution_time)

    # Measure DFS execution time
    start_time = time.time()
    dfs_depth = dfs(lis, goal)
    end_time = time.time()
    dfs_execution_time = end_time - start_time
    dfs_execution_times.append(dfs_execution_time)

# Plotting the bar chart
plt.bar(input_sizes, bfs_execution_times, label='BFS')
plt.bar(input_sizes, dfs_execution_times, label='DFS')
plt.xlabel('Input Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Time Comparison - BFS vs DFS')
plt.legend()
plt.show()

# %% [markdown]
# TASK 3

# %%
import heapq

# Define the maze as a 2D grid with nodes represented by characters
maze = [
    ['A', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', ' ', '#', '#', '#', '#'],
    [' ', ' ', ' ', ' ', ' ', ' ', ' '],
    ['#', '#', 'Y', '#', '#', '#', '#']
]

# Define the heuristic function as the Manhattan distance between two points
def heuristic(node, goal):
    x1, y1 = node
    x2, y2 = goal
    return abs(x1 - x2) + abs(y1 - y2)

# Define the A* search algorithm
def astar_search(maze, start, goal):
    # Define the directions: Up, Down, Left, Right
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    # Initialize the priority queue with the start node
    queue = [(0, start)]
    heapq.heapify(queue)

    # Initialize the cost and came_from dictionaries
    cost = {start: 0}
    came_from = {start: None}

    while queue:
        # Get the node with the lowest priority (cost + heuristic)
        current_cost, current_node = heapq.heappop(queue)

        # Check if the current node is the goal
        if current_node == goal:
            break

        # Explore the neighbors of the current node
        for dx, dy in directions:
            x, y = current_node
            neighbor = (x + dx, y + dy)

            # Check if the neighbor is a valid node
            if 0 <= neighbor[0] < len(maze) and 0 <= neighbor[1] < len(maze[0]) and maze[neighbor[0]][neighbor[1]] != '#':
                # Calculate the cost of reaching the neighbor node
                new_cost = cost[current_node] + 1

                # Update the cost and came_from dictionaries if the new cost is lower
                if neighbor not in cost or new_cost < cost[neighbor]:
                    cost[neighbor] = new_cost
                    priority = new_cost + heuristic(neighbor, goal)
                    heapq.heappush(queue, (priority, neighbor))
                    came_from[neighbor] = current_node

    # Reconstruct the path from the goal to the start if a path exists
    if goal in came_from:
        path = []
        current_node = goal
        while current_node != start:
            path.append(current_node)
            current_node = came_from[current_node]
        path.append(start)

        # Reverse the path to obtain the correct order
        path.reverse()

        return path
    else:
        return None

# Define the start and goal positions
start = (0, 0)
goal = (len(maze) - 1, len(maze[0]) - 1)

# Find the path using A* search
path = astar_search(maze, start, goal)

# Print the resulting path if it exists
if path is not None:
    for node in path:
        x, y = node
        maze[x][y] = '*'

    for row in maze:
        print(' '.join(row))
else:
    print("No path found.")
# Out:
# No path found.

# %% [markdown]
# **Task 4**

# %%
import math

def minimax_alpha_beta(node, depth, alpha, beta, maximizing_player):
    if depth == 0 or node.is_terminal():
        return node.evaluate(), None

    if maximizing_player:
        max_eval = -math.inf
        best_move = None
        for move in node.generate_moves():
            child_node = node.make_move(move)
            eval, _ = minimax_alpha_beta(child_node, depth - 1, alpha, beta, False)
            if eval > max_eval:
                max_eval = eval
                best_move = move
            alpha = max(alpha, max_eval)
            if beta <= alpha:
                break  # Beta cutoff
        return max_eval, best_move
    else:
        min_eval = math.inf
        best_move = None
        for move in node.generate_moves():
            child_node = node.make_move(move)
            eval, _ = minimax_alpha_beta(child_node, depth - 1, alpha, beta, True)
            if eval < min_eval:
                min_eval = eval
                best_move = move
            beta = min(beta, min_eval)
            if beta <= alpha:
                break  # Alpha cutoff
        return min_eval, best_move

# Example usage
class Node:
    def __init__(self, value):
        self.value = value

    def evaluate(self):
        return self.value

    def generate_moves(self):
        return [self.value - 1, self.value - 2, self.value - 3]  # Example moves

    def make_move(self, move):
        return Node(move)

    def is_terminal(self):
        return self.value <= 0

root_node = Node(10)  # Example initial node
depth = 3
alpha = -math.inf
beta = math.inf
maximizing_player = True
best_eval, best_move = minimax_alpha_beta(root_node, depth, alpha, beta, maximizing_player)
print("Best move:", best_move)
print("Best evaluation:", best_eval)
# Out:
# Best move: 9
# Best evaluation: 5
